# %%
### CHECANDO DADOS 

import pandas as pd 
import json as js

arquivo = pd.read_json('meiosPagamento19_23.json')

data_frame = pd.DataFrame(arquivo)

display(data_frame)
# Out:
#                                        @odata.context  \
# 0   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 1   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 2   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 3   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 4   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 5   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 6   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 7   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 8   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 9   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 10  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 11  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 12  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 13  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 14  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 15  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# ...

# %%
### TRATRAMENTO E ORGANIZAÇAO DE DADOS

import pandas as pd 
import json as js

arquivo = pd.read_json('meiosPagamento19_23.json')

dados_reais= arquivo['value']
dados_lista = list(dados_reais)
dados_json = js.dumps(dados_lista)

data_frame = pd.read_json(dados_json)
print(data_frame.dtypes)
display(data_frame)
# data_frame.to_csv('pagamentosOnline.csv')
# Out:
# datatrimestre               object
# valorPix                   float64
# valorTED                   float64
# valorCheque                float64
# valorBoleto                float64
# valorDOC                   float64
# valorCartaoCredito         float64
# valorCartaoDebito          float64
# quantidadePix              float64
# quantidadeTED              float64
# quantidadeCheque           float64
# quantidadeBoleto           float64
# quantidadeDOC              float64
# quantidadeCartaoCredito    float64
# quantidadeCartaoDebito     float64
# dtype: object
# /tmp/ipykernel_4950/3946546946.py:12: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frame = pd.read_json(dados_json)
#    datatrimestre    valorPix     valorTED  valorCheque  valorBoleto  valorDOC  \
# 0     2023-09-30  4493206.46   9960251.89    217017.83   2294274.40  10131.89
# ...
